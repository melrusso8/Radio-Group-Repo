# %% [markdown]
# # Lab 2 Presentation 1

# %%
import ugradio
import numpy as np

import ugradio.pico as pico
import ugradio.dft as dft
import ugradio.doppler as doppler
import ugradio.nch as nch
import ugradio.timing as timing

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from ipywidgets import interact, FloatSlider, Layout

import astropy
import unittest

# %% [markdown]
# ## Jen : Gather Data

# %%
#cold_data_1 = np.load('../Data/big_horn_data_1000.npy.zip')
#cal_data_1 = np.load('../Data/big_horn_data_1000.npz.zip')
cold_data_2 = np.load('../Data/50mV cold data.npz')
cal_data_2 = np.load('../Data/50mV data with rain.npz')

# %% [markdown]
# ## Combine Real and Complex Signal Components

# %%
#cold_data = cold_data_1['big_horn_data_1000'][0] - (cold_data_1["big_horn_data_1000"][1]*5/4*1j)
#cal_data = cal_data_1['big_horn_data_1000'][0] - (cal_data_1["big_horn_data_1000"][1]*5/4*1j)

cold_data = cold_data_2['arr_0'][0] - (cold_data_2["arr_0"][1]*5/4*1j) #SKY
cal_data = cal_data_2['arr_0'][0] - (cal_data_2["arr_0"][1]*5/4*1j) #RAIN 

#cold_data = galactic_data[0] - (galactic_data[1]*5/4*1j)

# %% [markdown]
# ## Resize Blocks

# %%
# resize blocks
cold_data.shape = (-1, 2000)
cal_data.shape = (-1, 2000)

# %%
cal_data.shape
# Out:
# (800, 2000)

# %%
cold_data.shape
# Out:
# (8000, 2000)

# %% [markdown]
# ## Plot Raw Horn Data

# %%
plt.figure(figsize=(15, 8))
plt.plot(cold_data[0]/2**16, "mediumpurple", label="Cold")
plt.plot(cal_data[0]/2**16, "dodgerblue", label="Blackbody")
plt.xlabel("Samples", fontsize=15)
plt.ylabel("Voltage (V)", fontsize=15)
plt.title("Cold and Blackbody Horn Data", fontsize=25)
plt.legend(fontsize=15)
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Olivia : Calculate Average Power Spectra of s_cold

# %%
# COLD DATA, SKY DATA, S_OFF BECAUSE WE DID NOT OBSERVE HYDROGEN IN THIS CAPTURE
freq = np.fft.fftfreq(cold_data.shape[1], 1/62.5e6)
freq = np.fft.fftshift(freq)/1e6

blocks = 8000
avg_power_array = []
for n in range (0, blocks):
    data_new = cold_data[n]
    ft = np.fft.fft(data_new)
    ft = np.fft.fftshift(ft)
    power = abs(ft)**2
    avg_power_array.append(power)
    
avg_power_array = np.mean(avg_power_array, axis = 0)
s_cold = avg_power_array

# %% [markdown]
# ## Plot Average Power Spectra of s_cold

# %%
plt.figure(figsize=(15,8))
plt.plot(freq + 1230 + 190, avg_power_array, "mediumpurple", linewidth=2)
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Average Power Spectrum of Cold Data", fontsize=25)
plt.legend(fontsize=15)

#plt.xlim(-2, 2)
#plt.vlines(1420.4058, ymin=10e8, ymax=10e11, linewidth=.5)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Calculate Average Power Spectra of s_cal

# %%
# CAL DATA, RAIN DATA, WHICH IS S_ON BECAUSE WE DO SEE THE HYDROGEN LINE
cal_freq = np.fft.fftfreq(cal_data.shape[1], 1/62.5e6)
cal_freq = np.fft.fftshift(cal_freq)/1e6

blocks = 800
avg_rain_power_array = []
for n in range (0, blocks):
    data_new = cal_data[n]
    ft = np.fft.fft(data_new)
    ft = np.fft.fftshift(ft)
    power = abs(ft)**2
    avg_rain_power_array.append(power)
    
avg_rain_power_array = np.mean(avg_rain_power_array, axis=0)
s_cal = avg_rain_power_array

# %% [markdown]
# ## Plot Average Power Spectra of s_cal

# %%
#%matplotlib notebook
plt.figure(figsize=(15,8))
plt.plot(cal_freq + 1230 + 190, avg_rain_power_array, "dodgerblue", linewidth=2)
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Average Power Spectrum of Blackbody Data", fontsize=25)
plt.legend(fontsize=15)
#plt.xlim(-1, 1)
#plt.vlines(1420.4058, ymin=10e8, ymax=10e11, linewidth=.5)
# Out:
# No handles with labels found to put in legend.

# %%
#%matplotlib notebook

plt.figure(figsize=(15,8))
plt.plot(freq + 1230 + 190, avg_power_array, "mediumpurple", linewidth=3, label="cold")
plt.plot(cal_freq + 1230 + 190, avg_rain_power_array, "dodgerblue", linewidth=2, label="blackbody")
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Overlapping Average Power Spectra of Calibration Data", fontsize=25)
plt.legend(fontsize=15)
#plt.xlim(-1, 1)
#plt.vlines(1420.4058, ymin=10e8, ymax=10e11, linewidth=.5)

# %% [markdown]
# # Madeline : Estimate Optimal Time Range for Galactic Plane Observation

# %%
from astropy.coordinates import EarthLocation, SkyCoord

# %%
# assumes we are at campbell
ugradio.timing.lst()
# Out:
# 1.5669067027030323

# %%
# ideal HI viewing time is at LST = 19 - 6
galactic_data_source = np.load('../Data/Galaxy Data 1000.npz')

# %% [markdown]
# ### Combine complex and real components and resize blocks

# %%
galactic_data = galactic_data_source['arr_0'][0] - (galactic_data_source["arr_0"][1]*5/4*1j)

# resize blocks
galactic_data.shape = (-1, 2000)
galactic_data.shape
# Out:
# (8000, 2000)

# %% [markdown]
# ### Calculate average power spectrum

# %%
# GALACTIC DATA, S_ON BECAUSE WE ARE OBSERVING HYDROGEN LINE
galactic_freq = np.fft.fftfreq(galactic_data.shape[1], 1/62.5e6)
galactic_freq = np.fft.fftshift(galactic_freq)/1e6

blocks = 8000
avg_galactic_power_array = []
for n in range (0, blocks):
    data_new = galactic_data[n]
    ft = np.fft.fft(data_new)
    ft = np.fft.fftshift(ft)
    power = abs(ft)**2
    avg_galactic_power_array.append(power)
    
avg_galactic_power_array = np.mean(avg_galactic_power_array, axis = 0)
s_on = avg_galactic_power_array
g_freq = galactic_freq + 1230 + 190

# %% [markdown]
# ### Plot average power spectrum

# %%
#%matplotlib notebook
plt.figure(figsize=(15,8))
plt.plot(g_freq, avg_galactic_power_array, "purple", linewidth=2, label="Galactic Plane Power Spectrum")
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Average Power Spectrum of Galactic Data", fontsize=25)

#plt.xlim(-2, 2)
plt.vlines(1420.4058, ymin=0, ymax=10e11, linestyle="dashed", linewidth=.5, label="HI Line")

plt.legend(fontsize=15)

# %%
#%matplotlib notebook
plt.figure(figsize=(15,8))
plt.plot(g_freq, avg_galactic_power_array, "purple", linewidth=2, label="Galactic Plane Power Spectrum")
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Average Power Spectrum of Galactic Data", fontsize=25)

plt.xlim(1419, 1422)
plt.ylim(10e8, 10e12)
plt.vlines(1420.4058, ymin=0, ymax=10e11, linestyle="dashed", linewidth=.5, label="HI Line")
plt.legend(fontsize=15)

# %% [markdown]
# ## Calculate S_off from S_on spectrum

# %%
#%matplotlib notebook
plt.figure(figsize=(15,8))
plt.plot(g_freq, avg_galactic_power_array, "purple", linewidth=2, label="Galactic Plane Power Spectrum")
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Average Power Spectrum of Galactic Data", fontsize=25)

#plt.xlim(-2, 2)
plt.vlines(g_freq[800], ymin=0, ymax=10e11, linestyle="dashed", linewidth=.5, label="range limit")
plt.vlines(g_freq[990], ymin=0, ymax=10e11, linestyle="dashed", linewidth=.5)
plt.legend(fontsize=15)

# %%
s_off_avg = np.mean(s_on[800:990])
s_off_avg
# Out:
# 26680638526.057976

# %% [markdown]
# # Mel : Calculate Gain and T_line

# %% [markdown]
# ### find T_sys

# %%
# temperature
T_rx = 300 #kelvin
T_sky = 10 #between 10-100K
T_sys = T_rx - T_sky
T_sys
# Out:
# 290

# %% [markdown]
# ### filter out spikes

# %%
filtered_s_cold = np.array([s for s in s_cold if not (g_freq[list(s_cold).index(s)]<1390 or g_freq[list(s_cold).index(s)]>1451 or (g_freq[list(s_cold).index(s)]< 1421 and g_freq[list(s_cold).index(s)]>1419))])
filtered_s_cal = np.array([s for s in s_cal if not (g_freq[list(s_cal).index(s)]<1390 or g_freq[list(s_cal).index(s)]>1451 or (g_freq[list(s_cal).index(s)]< 1421 and g_freq[list(s_cal).index(s)]>1419))])
print(len(filtered_s_cold), len(filtered_s_cal))
# Out:
# 1890 1890

# %% [markdown]
# ## Plot Filtered S_cold and S_cal

# %%
filtered_freq = np.fft.fftfreq(filtered_s_cold.shape[0], 1/62.5e6)
filtered_freq = np.fft.fftshift(filtered_freq)/1e6

plt.figure(figsize=(15,8))
plt.plot(filtered_freq + 1230 + 190, filtered_s_cold, "purple", linewidth=2, label="s_cold")
plt.plot(filtered_freq + 1230 + 190, filtered_s_cal, "blue", linewidth=2, label="s_cal")
plt.yscale("log")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Power", fontsize=15)
plt.title("Power Spectrum of Filtered S_cal and S_cold", fontsize=25)
plt.legend()

# %% [markdown]
# ### calculate G and T_line

# %%
s_line = s_on / s_off_avg  #s_off=s_cold #GALACTIC POWER SPECTRA / SKY POWER SPECTRA #probably wrong. ratio of on observation (hydrogen there), over off observation (no H)
G = T_sys/(np.sum(filtered_s_cal - filtered_s_cold)) * np.sum(filtered_s_cold)
T_line = (s_line - 1) * G #power spectra in temperature units
T_line[1000] = 0

# %%
print("Gain G = " + str(G))
# Out:
# Gain G = 465.9025664952673

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
plt.plot(g_freq, T_line, "r", label="s_on")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Calibrated Galactic Data over Frequency", fontsize=25)
#plt.legend(fontsize=15)
#plt.yscale("log")
plt.vlines(g_freq[950], ymin=0, ymax=10e1, linestyle="dashed", linewidth=.5, label="range limit")
plt.vlines(g_freq[1060], ymin=0, ymax=10e1, linestyle="dashed", linewidth=.5)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
plt.figure(figsize=(10,5))
plt.plot(g_freq[950:1060], T_line[950:1060], "r", label="s_on")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
#plt.legend(fontsize=15)
#plt.yscale("log")
#plt.vlines(g_freq[980], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5, label="range limit")
#plt.vlines(g_freq[1030], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'Zoomed in Calibrated Galactic Data over Frequency')

# %% [markdown]
# # $v/c = - \Delta \nu / \nu_0$

# %%
calibrated_data = T_line
list1 = calibrated_data.tolist()
list1.remove(max(list1))
nu_1 = g_freq[list1.index(max(list1))+1]

# %%
nu_1
# Out:
# 1420.53125

# %%
nu_0 = 1420.4
delta_nu = nu_1 - nu_0
c = 2.99792458 * 10**8

# %%
delta_nu
# Out:
# 0.13124999999990905

# %%
doppler_velocity = - delta_nu/nu_0*c/1000

# %%
doppler_velocity
# Out:
# -27.701886871636674

# %%
#doppler_v_axis = [-(s-1420.4)/1420.4*c for s in g_freq]
doppler_v_axis = -(g_freq-1420.4)/1420.4*c/1000

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
plt.plot(doppler_v_axis, T_line, "r", label="s_on")
plt.xlabel("Velocity (km/s)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Calibrated Galactic Data over Observed Doppler Velocity", fontsize=25)
plt.yscale("log")
plt.vlines(doppler_velocity, ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5, label="Doppler Velocity")
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Calculate Doppler Correction

# %%
dec = nch.lat
jd = ugradio.timing.julian_date(1613674800)
ra = ugradio.timing.lst(jd)

# %%
v = ugradio.doppler.get_projected_velocity(ra, dec, jd)

# %%
v_float = v.to_value('km/s')
v_float
# Out:
# -19.943701007675738

# %%
dist_to_sun = 1.5e8 #km
orbit_dist = 2*np.pi*dist_to_sun
orbit_v = orbit_dist/(np.pi*1e7) #60*60*24*365
galactic_orbit_v = 220 #km/s
orbit_v # maximum error contribution from orbital velocity
# Out:
# 29.999999999999996

# %%
# %matplotlib notebook
plt.figure(figsize=(10,5))
plt.plot(doppler_v_axis - v_float, T_line, "r", label="s_on")
plt.xlabel("Velocity (km/s)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Calibrated Galactic Data over LSR Doppler Velocity", fontsize=25)
plt.yscale("log")
plt.vlines(doppler_velocity - v_float, ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5, label="LSR Doppler Velocity")
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Gaussian Fit

# %%
g_freq_fit = g_freq[950:1060]
T_line_fit = T_line[950:1060]

# %%
plt.figure(figsize=(10,5))
plt.plot(g_freq_fit, T_line_fit, "r", label="s_on")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
#plt.legend(fontsize=15)
#plt.yscale("log")
#plt.vlines(g_freq[980], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5, label="range limit")
#plt.vlines(g_freq[1030], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5)
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0.5, 1.0, 'Zoomed in Calibrated Galactic Data over Frequency')

# %%
d = {'amp' : 100, 'avg':1420.5, 'sig': .1}

# %%
poly_fit = np.polyfit(g_freq_fit, T_line_fit, 2)
poly_fit
# Out:
# array([-7.17271677e+00,  2.03841142e+04, -1.44823584e+07])

# %%
poly_val = np.polyval(poly_fit, g_freq_fit)
#poly_val

# %%
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "b", label="s_on")
plt.plot(g_freq_fit, poly_val, "r", label="polynomial fit")
#plt.plot(g_freq_fit, gauss_val, "y", label="gauss fit")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
#plt.yscale("log")
#plt.vlines(g_freq[980], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5, label="range limit")
#plt.vlines(g_freq[1030], ymin=0, ymax=10e3, linestyle="dashed", linewidth=.5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
from ugradio import gauss
from scipy.optimize import fmin

# %%
# 
# fit low values with polynomial. fit peak with gaussian. 
# sum these functions

# %%
gauss_fit = ugradio.gauss.gaussfit(g_freq_fit, T_line_fit, **d)
gauss_fit
# Out:
# {'amp': array([82.41432831]),
#  'avg': array([1420.50456856]),
#  'sig': array([0.10393012])}

# %%
gauss_val = ugradio.gauss.gaussval(g_freq_fit, **gauss_fit)
gauss_val
# Out:
# array([1.04318548e-84, 3.94398341e-82, 1.36220979e-79, 4.29821648e-77,
#        1.23899040e-74, 3.26274376e-72, 7.84934400e-70, 1.72511927e-67,
#        3.46369994e-65, 6.35326200e-63, 1.06460534e-60, 1.62973083e-58,
#        2.27917930e-56, 2.91190012e-54, 3.39867647e-52, 3.62391953e-50,
#        3.53006445e-48, 3.14139171e-46, 2.55385904e-44, 1.89673702e-42,
#        1.28692337e-40, 7.97689038e-39, 4.51699833e-37, 2.33669272e-35,
#        1.10430401e-33, 4.76772355e-32, 1.88048056e-30, 6.77582221e-29,
#        2.23043990e-27, 6.70740325e-26, 1.84269594e-24, 4.62475052e-23,
#        1.06037214e-21, 2.22107733e-20, 4.25015158e-19, 7.42985824e-18,
#        1.18656629e-16, 1.73116656e-15, 2.30739034e-14, 2.80956223e-13,
#        3.12529928e-12, 3.17599593e-11, 2.94851697e-10, 2.50070635e-09,
#        1.93756879e-08, 1.37147196e-07, 8.86853950e-07, 5.23905124e-06,
#        2.82740849e-05, 1.39399058e-04, 6.27865309e-04, 2.58350025e-03,
#        9.71149065e-03, 3.33502163e-02, 1.04627725e-01, 2.99868108e-01,
#        7.85143692e-01, 1.87803370e+00, 4.10386426e+00, 8.19252852e+00,
#        1.49409532e+01, 2.48928155e+01, 3.78882985e+01, 5.26831283e+01,
#        6.69226881e+01, 7.76623573e+01, 8.23347421e+01, 7.97427226e+01,
#        7.05560662e+01, 5.70312681e+01, 4.21140556e+01, 2.84103428e+01,
#        1.75089963e+01, 9.85783168e+00, 5.07033804e+00, 2.38247197e+00,
#        1.02271366e+00, 4.01065846e-01, 1.43685411e-01, 4.70267576e-02,
#        1.40608887e-02, 3.84074851e-03, 9.58416634e-04, 2.18488299e-04,
#        4.55027238e-05, 8.65729016e-06, 1.50474158e-06, 2.38933608e-07,
#        3.46599498e-08, 4.59318552e-09, 5.56077617e-10, 6.15024208e-11,
#        6.21418783e-12, 5.73603657e-13, 4.83698584e-14, 3.72625945e-15,
#        2.62244708e-16, 1.68607056e-17, 9.90330440e-19, 5.31397957e-20,
#        2.60492367e-21, 1.16655573e-22, 4.77255950e-24, 1.78374423e-25,
#        6.09044716e-27, 1.89977054e-28, 5.41362895e-30, 1.40932512e-31,
#        3.35173187e-33, 7.28220190e-35])

# %%
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "b", label="s_on")
plt.plot(g_freq_fit, poly_val, "r", label="polynomial fit")
plt.plot(g_freq_fit, gauss_val, "pink", label="gauss fit")
#plt.plot(g_freq_fit, gauss_val, "y", label="gauss fit")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
gauss_val.size
# Out:
# 110

# %%
left_poly = poly_val[0:60]
mid_gauss = gauss_val[61:75]
right_poly = poly_val[76:110]

# %%
#this is wrong
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit[0:60], left_poly, "b", label="poly")
plt.plot(g_freq_fit[61:75], mid_gauss, "r", label="gauss")
plt.plot(g_freq_fit[76:110], right_poly, "pink", label="poly 2")
#plt.plot(g_freq_fit, gauss_val, "y", label="gauss fit")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#left side
g_freq_fit = g_freq[950:1060]
T_line_fit = T_line[950:1060]
poly_fit_left = np.polyfit(g_freq_fit[0:60], T_line_fit[0:60], 2)

poly_val_left = np.polyval(poly_fit_left, g_freq_fit[0:60])

# %%
#g_freq_fit = g_freq[950:1060]
#T_line_fit = T_line[950:1060]
#freq_left = g_freq[950,1012]
#T_line_left = T_line[950:1012]
#poly_fit_left = np.polyfit(freq_left, T_line_fit, 2)

#poly_val_left = np.polyval(poly_fit_left, freq_left)

# %%
#right side

poly_fit_right = np.polyfit(g_freq_fit[70:110], T_line_fit[70:110], 2)

poly_val_right = np.polyval(poly_fit_right, g_freq_fit[70:110])

# %%
#middle
gauss_fit_mid = ugradio.gauss.gaussfit(g_freq_fit[60:70], T_line_fit[60:70], **d)

gauss_val_mid = ugradio.gauss.gaussval(g_freq_fit[60:70], **gauss_fit)

# %%
fit_line_new = np.concatenate((poly_val_left,gauss_val_mid,poly_val_right))
print(len(fit_line_new))
# Out:
# 110

# %%
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "r", label="s_on")
plt.plot(g_freq_fit, fit_line_new, "b", label="poly")

plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#better fit
d = {'amp' : 120, 'avg':1420.5, 'sig': 0.08}
#middle
gauss_fit_mid_new = ugradio.gauss.gaussfit(g_freq_fit[61:70], T_line_fit[61:70], **d)

gauss_val_mid_new = ugradio.gauss.gaussval(g_freq_fit[61:70], **gauss_fit_mid_new)
print(gauss_fit_mid_new)
#sig=stndard deviation of gauss, relate standard deviation to full width half max
#width = 2*((2*ln(2))**(0.5))*sig
# Out:
# {'amp': array([93.63801803]), 'avg': array([1420.49856593]), 'sig': array([0.07731398])}

# %%
#left side better
g_freq_fit = g_freq[950:1060]
T_line_fit = T_line[950:1060]
poly_fit_left2 = np.polyfit(g_freq_fit[0:61], T_line_fit[0:61], 2)

poly_val_left2 = np.polyval(poly_fit_left2, g_freq_fit[0:61])

# %%
fit_line_new_2 = np.concatenate((poly_val_left2,gauss_val_mid_new,poly_val_right))
print(len(fit_line_new_2))
# Out:
# 110

# %%
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "r--", label="s_on")
plt.plot(g_freq_fit, fit_line_new_2, "b", label="new")
#plt.plot(g_freq_fit, fit_line_new, "g", label="old")

plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)

#subtract the polynomial fit
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
line_new = T_line_fit

# %%
subtract_left = line_new[0:61] - poly_val_left2
subtract_right = line_new[70:110] - poly_val_right

# %%
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "r--", label="s_on")
plt.plot(g_freq_fit[0:61], subtract_left, "b", label="left")
plt.plot(g_freq_fit[70:110], subtract_right, "b", label="right")
#plt.plot(g_freq_fit, fit_line_new, "g", label="old")

plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)

#subtract the polynomial f
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fit_line_new_3 = np.concatenate((subtract_left,gauss_val_mid_new,subtract_right))

# %%
plt.figure(figsize=(8,5))
#plt.plot(g_freq_fit, T_line_fit, "r--", label="s_on")
plt.plot(g_freq_fit, fit_line_new_3, "b", label="nice")
plt.plot(g_freq_fit, fit_line_new_2, "r", label="old")



plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Find kinetic temperature

# %%
#1/2mv^2=KT 
#v= (2KT/m)^0.5
#T=1/2mv^2/k
plt.figure(figsize=(8,5))
plt.plot(g_freq_fit, T_line_fit, "r", label="s_on")
plt.xlabel("Frequency (MHz)", fontsize=15)
plt.ylabel("Brightness Temperature (K)", fontsize=15)
#plt.title("Zoomed in Calibrated Galactic Data over Frequency", fontsize=25)
plt.legend(fontsize=15)
plt.vlines(g_freq[1010], ymin=0, ymax=100, linestyle="dashed", linewidth=.5)
plt.vlines(g_freq[1021], ymin=0, ymax=100, linestyle="dashed", linewidth=.5)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
#use sig as width
#fix value
delta_nu = g_freq[1021]-g_freq[1010]

# %%
#convert to velocity
doppler_v_axis = -(g_freq-1420.4)/1420.4*c/1000
delta_v = doppler_v_axis[1021]-doppler_v_axis[1010] #m/s

# %%
#find temp
#T=1/2mv^2/k
m=1.6726219*(10e-27) #kg
k=1.380649*(10e-23) #kg m^2 /s^2 K
temp = (0.5*delta_v**2*m)/k

# %%
print(temp)
# Out:
# 0.31885262206250836

# %%
sig = 0.07731398
delta_nu = sig*u.Hz
delta_nu=delta_nu.to(1/u.s)
nu_0 = 1420.4*u.MHz
nu_0 = nu_0.to(1/u.s)
c = 299792458*u.m/u.s
k =1.380649*(10e-23)*u.kg*(u.m**2)/((u.s**2)*u.K)
m=1.6726219*(10e-27)*u.kg 
#delta_nu = ((nu_0)/c)*((2*k*temp/m)**0.5)
temp = (((delta_nu*c)/nu_0)**2)*(m/(2*k))
#temp_wrong = 1.612949×10−8
# Out:
# <Quantity 1.61294902e-08 K>

# %%
#use astropy units
from astropy import units as u
from astropy import constants

# %%
#error calculation

_,gauss_fit_error = ugradio.gauss.gaussfit(g_freq_fit[61:70], T_line_fit[61:70], return_cov=True, **d)

# %%
gauss_fit_error #covariance matrix, tells how unceratin parameters are, offdiagonal values show correlation 
#elements in diagonal show variance in amp, avg, sig
#squareroot of elemtns in diagonal is the uncertainty 
amp_error = ((np.diag(gauss_fit_error)[0])**0.5)
avg_error = ((np.diag(gauss_fit_error)[1])**0.5)
sig_error = ((np.diag(gauss_fit_error)[2])**0.5)
print(amp_error)
print(avg_error)
print(sig_error)
# Out:
# 5.107832756040398
# 0.005135982508468316
# 0.005903021644032389

# %%
#gives uncertainty of kinetic temperature 
#take the derivative of kinetic temperature with respect to delta nu and 
#then multiply by standard deviation of delta nu

# %%
#temp = (d/delta_nu)*(((delta_nu*c)/nu_0)**2)*(m/(2*k))
der_temp = 2*delta_nu*(((c)/nu_0)**2)*(m/(2*k))
st_dv = sig*u.Hz
st_dv= st_dv.to(1/u.s)
temp_error = der_temp*st_dv
temp_error
# Out:
# <Quantity 3.22589803e-08 K>
