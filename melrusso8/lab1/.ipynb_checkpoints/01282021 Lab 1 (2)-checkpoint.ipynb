# %% [markdown]
# # Lab 1 : Week 2

# %%
import numpy as np
import pandas as pd

import ugradio
import ugradio.pico as pico
import ugradio.dft as dft

import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from ipywidgets import interact, FloatSlider, Layout

# %% [markdown]
# ## import data from data.npz file
# ### sample electronic signals and convert them into digital signals

# %%
imported_data = np.load("data.npz")

# %%
imported_data.files
# Out:
# ['arr_0']

# %%
imported_data['arr_0']
# Out:
# array([[[ -9216,  11008, -12544, ...,  -6912,   4864,  -2560],
#         [-17152,  17408, -17152, ...,   7680,  -9472,  11264],
#         [-14848,  13824, -12288, ...,  15616, -16384,  16896]],
#
#        [[ 16640,   3584, -10496, ...,  -5632,   8960,  19712],
#         [-20480, -15104,  -2304, ...,  15872,   2304, -11520],
#         [ 19968,   9728,  -4864, ..., -11264,   2816,  15872]]],
#       dtype=int16)

# %% [markdown]
# ## extract and inspect data

# %%
imported_data['arr_0'].shape
# Out:
# (2, 3, 16000)

# %%
sig_a_data = imported_data["arr_0"][0,0, :200]
sig_a_data[:10]
# Out:
# array([ -9216,  11008, -12544,  14080, -15104,  16128, -16640,  17152,
#        -17152,  17152], dtype=int16)

# %%
sig_b_data = imported_data["arr_0"][1,0,:200]
sig_b_data[:10]
# Out:
# array([ 16640,   3584, -10496, -19200, -19200, -10240,   4096,  16896,
#         21248,  14848], dtype=int16)

# %% [markdown]
# ## create time array from sampling frequency = 62.5 MHz/N

# %%
data_length = len(sig_a_data)
N = 1
sampling_frequency_MHz = 62500/N
delta_t = 1/sampling_frequency_MHz
total_time = delta_t * data_length

# %%
times = np.arange(0, total_time, delta_t)

# %%
times
# Out:
# array([0.000e+00, 1.600e-05, 3.200e-05, 4.800e-05, 6.400e-05, 8.000e-05,
#        9.600e-05, 1.120e-04, 1.280e-04, 1.440e-04, 1.600e-04, 1.760e-04,
#        1.920e-04, 2.080e-04, 2.240e-04, 2.400e-04, 2.560e-04, 2.720e-04,
#        2.880e-04, 3.040e-04, 3.200e-04, 3.360e-04, 3.520e-04, 3.680e-04,
#        3.840e-04, 4.000e-04, 4.160e-04, 4.320e-04, 4.480e-04, 4.640e-04,
#        4.800e-04, 4.960e-04, 5.120e-04, 5.280e-04, 5.440e-04, 5.600e-04,
#        5.760e-04, 5.920e-04, 6.080e-04, 6.240e-04, 6.400e-04, 6.560e-04,
#        6.720e-04, 6.880e-04, 7.040e-04, 7.200e-04, 7.360e-04, 7.520e-04,
#        7.680e-04, 7.840e-04, 8.000e-04, 8.160e-04, 8.320e-04, 8.480e-04,
#        8.640e-04, 8.800e-04, 8.960e-04, 9.120e-04, 9.280e-04, 9.440e-04,
#        9.600e-04, 9.760e-04, 9.920e-04, 1.008e-03, 1.024e-03, 1.040e-03,
#        1.056e-03, 1.072e-03, 1.088e-03, 1.104e-03, 1.120e-03, 1.136e-03,
#        1.152e-03, 1.168e-03, 1.184e-03, 1.200e-03, 1.216e-03, 1.232e-03,
#        1.248e-03, 1.264e-03, 1.280e-03, 1.296e-03, 1.312e-03, 1.328e-03,
#        1.344e-03, 1.360e-03, 1.376e-03, 1.392e-03, 1.408e-03, 1.424e-03,
#        1.440e-03, 1.456e-03, 1.472e-03, 1.488e-03, 1.504e-03, 1.520e-03,
#        1.536e-03, 1.552e-03, 1.568e-03, 1.584e-03, 1.600e-03, 1.616e-03,
#        1.632e-03, 1.648e-03, 1.664e-03, 1.680e-03, 1.696e-03, 1.712e-03,
#        1.728e-03, 1.744e-03, 1.760e-03, 1.776e-03, 1.792e-03, 1.808e-03,
#        1.824e-03, 1.840e-03, 1.856e-03, 1.872e-03, 1.888e-03, 1.904e-03,
#        1.920e-03, 1.936e-03, 1.952e-03, 1.968e-03, 1.984e-03, 2.000e-03,
#        2.016e-03, 2.032e-03, 2.048e-03, 2.064e-03, 2.080e-03, 2.096e-03,
#        2.112e-03, 2.128e-03, 2.144e-03, 2.160e-03, 2.176e-03, 2.192e-03,
#        2.208e-03, 2.224e-03, 2.240e-03, 2.256e-03, 2.272e-03, 2.288e-03,
#        2.304e-03, 2.320e-03, 2.336e-03, 2.352e-03, 2.368e-03, 2.384e-03,
#        2.400e-03, 2.416e-03, 2.432e-03, 2.448e-03, 2.464e-03, 2.480e-03,
#        2.496e-03, 2.512e-03, 2.528e-03, 2.544e-03, 2.560e-03, 2.576e-03,
#        2.592e-03, 2.608e-03, 2.624e-03, 2.640e-03, 2.656e-03, 2.672e-03,
#        2.688e-03, 2.704e-03, 2.720e-03, 2.736e-03, 2.752e-03, 2.768e-03,
#        2.784e-03, 2.800e-03, 2.816e-03, 2.832e-03, 2.848e-03, 2.864e-03,
#        2.880e-03, 2.896e-03, 2.912e-03, 2.928e-03, 2.944e-03, 2.960e-03,
#        2.976e-03, 2.992e-03, 3.008e-03, 3.024e-03, 3.040e-03, 3.056e-03,
#        3.072e-03, 3.088e-03, 3.104e-03, 3.120e-03, 3.136e-03, 3.152e-03,
#        3.168e-03, 3.184e-03])

# %% [markdown]
# ## plot data over samples and over time

# %%
# signal A over samples
plt.figure(figsize=(10,5))
plt.xlim(0, 200)
plt.ylim(-40000,40000)
plt.xlabel("Samples")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal A (V) over Samples")
plt.plot(sig_a_data)

# %%
# signal A over time
plt.figure(figsize=(10,5))
plt.xlim(0, total_time)
plt.ylim(-40000,40000)
plt.xlabel("Time (s)")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal A (V) over Time")
plt.plot(times, sig_a_data)

# %%
# signal B over samples
plt.figure(figsize=(10,5))
plt.xlim(0, 200)
plt.ylim(-40000,40000)
plt.xlabel("Samples")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal B (V) over Samples")
plt.plot(sig_b_data)

# %%
# signal B over time
plt.figure(figsize=(10,5))
plt.xlim(0, total_time)
plt.ylim(-40000,40000)
plt.xlabel("Time (s)")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal B (V) over Time")
plt.plot(times, sig_b_data)

# %%
plt.figure(figsize=(10,5))
plt.xlim(0, 200)
plt.ylim(-40000,40000)
plt.xlabel("Samples")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal A and B (V) over Samples")
plt.legend(["Signal A", "Signal B"])
plt.plot(sig_b_data)
plt.plot(sig_a_data)

# %%
plt.figure(figsize=(10,5))
plt.xlim(0, total_time)
plt.ylim(-40000,40000)
plt.xlabel("Time (s)")
plt.ylabel("*2^(-16) Volts")
plt.title("Signal A and B (V) over Time")
plt.legend(["Signal A", "Signal B"])
plt.plot(times, sig_b_data)
plt.plot(times, sig_a_data)

# %% [markdown]
# ### does the period match what you expected?

# %% [markdown]
# ## take the fourier transform of data

# %%
dft.dft(sig_a_data, vsamp=1)
# Out:
# (array([-0.5  , -0.495, -0.49 , -0.485, -0.48 , -0.475, -0.47 , -0.465,
#         -0.46 , -0.455, -0.45 , -0.445, -0.44 , -0.435, -0.43 , -0.425,
#         -0.42 , -0.415, -0.41 , -0.405, -0.4  , -0.395, -0.39 , -0.385,
#         -0.38 , -0.375, -0.37 , -0.365, -0.36 , -0.355, -0.35 , -0.345,
#         -0.34 , -0.335, -0.33 , -0.325, -0.32 , -0.315, -0.31 , -0.305,
#         -0.3  , -0.295, -0.29 , -0.285, -0.28 , -0.275, -0.27 , -0.265,
#         -0.26 , -0.255, -0.25 , -0.245, -0.24 , -0.235, -0.23 , -0.225,
#         -0.22 , -0.215, -0.21 , -0.205, -0.2  , -0.195, -0.19 , -0.185,
#         -0.18 , -0.175, -0.17 , -0.165, -0.16 , -0.155, -0.15 , -0.145,
#         -0.14 , -0.135, -0.13 , -0.125, -0.12 , -0.115, -0.11 , -0.105,
#         -0.1  , -0.095, -0.09 , -0.085, -0.08 , -0.075, -0.07 , -0.065,
#         -0.06 , -0.055, -0.05 , -0.045, -0.04 , -0.035, -0.03 , -0.025,
#         -0.02 , -0.015, -0.01 , -0.005,  0.   ,  0.005,  0.01 ,  0.015,
#          0.02 ,  0.025,  0.03 ,  0.035,  0.04 ,  0.045,  0.05 ,  0.055,
#          0.06 ,  0.065,  0.07 ,  0.075,  0.08 ,  0.085,  0.09 ,  0.095,
#          0.1  ,  0.105,  0.11 ,  0.115,  0.12 ,  0.125,  0.13 ,  0.135,
#          0.14 ,  0.145,  0.15 ,  0.155,  0.16 ,  0.165,  0.17 ,  0.175,
#          0.18 ,  0.185,  0.19 ,  0.195,  0.2  ,  0.205,  0.21 ,  0.215,
#          0.22 ,  0.225,  0.23 ,  0.235,  0.24 ,  0.245,  0.25 ,  0.255,
#          0.26 ,  0.265,  0.27 ,  0.275,  0.28 ,  0.285,  0.29 ,  0.295,
#          0.3  ,  0.305,  0.31 ,  0.315,  0.32 ,  0.325,  0.33 ,  0.335,
#          0.34 ,  0.345,  0.35 ,  0.355,  0.36 ,  0.365,  0.37 ,  0.375,
#          0.38 ,  0.385,  0.39 ,  0.395,  0.4  ,  0.405,  0.41 ,  0.415,
#          0.42 ,  0.425,  0.43 ,  0.435,  0.44 ,  0.445,  0.45 ,  0.455,
#          0.46 ,  0.465,  0.47 ,  0.475,  0.48 ,  0.485,  0.49 ,  0.495]),
#  array([ 1.02400000e+03-4.31471080e-09j, -7.92639715e-01-6.05725715e+02j,
#          8.99390392e+02-5.50876148e+02j,  1.32387801e+03-6.58401426e+02j,
#         -9.22202053e+05+1.45895029e+06j,  2.06433371e+02+1.51716209e+03j,
#          3.61173286e+02+7.91707443e+02j,  2.84802919e+02+6.60812194e+02j,
#          1.11764468e+03+2.72241784e+02j,  5.99231492e+01+4.70426953e+02j,
#          3.57581375e+02+5.68635326e+02j,  9.82139010e+02+1.35203445e+02j,
#         -1.38818999e+03+6.72380866e+02j, -4.77381430e+02+1.10981470e+03j,
#          3.19842596e+02+7.00537902e+02j,  6.10910706e+02+9.79555454e+02j,
#          7.35037785e+01+6.79948267e+02j, -4.42658977e+02+8.24099991e+02j,
#         -3.17029302e+02+4.21787705e+02j,  1.12639202e+03+1.77668707e+02j,
#          9.77832989e+01+1.27482792e+03j, -8.90254523e+02+9.76389271e+02j,
#         -4.69302817e+02+3.57142165e+02j,  3.24134323e+02+1.28592161e+02j,
#         -4.18600761e+02-1.01698827e+02j,  4.37019336e+02+6.93019336e+02j,
#         -1.20328320e+02+6.85178164e+02j,  8.12332671e+02+7.90168480e+02j,
#          1.24639161e+03-1.56329896e+03j, -1.02850674e+03-8.25567673e+01j,
#         -3.22578819e+02-6.76362118e+02j,  9.07759574e+02-4.93957983e+02j,
#         -9.23845718e+01+1.39748037e+02j,  7.81718353e+02+1.14406426e+03j,
#         -4.85663946e+02+5.83063261e+02j,  3.01914046e+02+4.87280925e+02j,
#         -1.06790137e+03+8.56008226e+02j, -1.78242637e+01-3.08222435e+02j,
#         -2.43082013e+01-2.69026890e+02j,  3.07528161e+02-2.15512536e+02j,
#         -2.56000000e+02+1.85994887e+02j,  7.42244584e+02+6.74330858e+02j,
#         -5.63507645e+00+1.59201090e+02j,  2.39586874e+02+8.06457068e+02j,
#         -1.40380392e+03-8.11813764e+02j, -1.60092772e+02-2.73656516e+00j,
#         -4.35194618e+02-2.34837940e+02j, -2.83417957e+02-4.48475519e+02j,
#          4.28437961e+02+3.20436285e+02j,  3.55440425e+02+7.89590247e+02j,
#         -2.56000000e+02+2.56000000e+02j, -7.98288412e+02+6.89299804e+02j,
#          2.18756196e+02-2.73301123e+02j, -1.75019765e+01-3.42403613e+02j,
#         -6.07199602e+01+1.47923795e+01j, -6.55572400e+02+1.67770969e+02j,
#          2.67381825e+02+7.74966502e+02j, -1.14665044e+03+1.44665959e+02j,
#         -4.43033944e+02-7.88433027e+02j, -6.31402050e+02-1.43150892e+02j,
#          6.70216701e+02-1.14951162e+02j, -7.87871408e+01+8.13701818e+01j,
#         -3.48923736e+02+3.07027893e+02j, -1.01393430e+03-1.83924066e-01j,
#          4.02836711e+02+2.02914737e+02j, -1.31802285e+03-6.42098526e+02j,
#          2.11320627e+02-8.71212007e+02j, -3.04656179e+02-2.83248168e+01j,
#          7.79431868e+02+2.57725501e+02j, -3.89600129e+02-2.63364327e+02j,
#          1.64362118e+02-1.89421181e+02j,  2.36652191e+02+8.60539859e+01j,
#          6.80828765e+02+6.76299813e+02j, -1.47537359e+03-3.16664553e+02j,
#          8.81795736e+01-6.14817081e+02j,  7.49806640e+01-3.30980664e+02j,
#         -4.77938856e+02-2.06651300e+02j,  1.47028132e+02+2.76212733e+01j,
#          5.65242050e+02+3.47526855e+02j,  7.30017956e+02+7.68040482e+02j,
#         -2.56000000e+02+7.87886986e+02j, -1.09586482e+03-4.56329432e+02j,
#          5.35028299e+02-1.69824977e+02j,  7.12060677e+02+3.52687152e+02j,
#         -4.48275448e+02-4.59270546e+02j, -4.23235309e+02+4.52068101e+02j,
#          6.51848668e+00+5.13766769e+01j,  1.07314200e+03+4.91310306e+02j,
#         -7.03443324e+02+6.88356999e+02j, -2.19050873e+02+1.77427718e+02j,
#          5.66353260e+01+8.69581375e+02j, -1.06468190e+02+6.74924573e+02j,
#         -1.97641737e+03+1.21772250e+03j, -3.93664811e+02-1.29320146e+02j,
#          1.14872275e+02-2.61364124e+02j,  9.25665203e+02+7.13787747e+02j,
#         -1.75620506e+03+6.16018605e+02j, -1.25620035e+02-5.90137582e+01j,
#         -3.91427665e+02+3.90815381e+02j, -2.09081538e+02+8.29894020e+01j,
#          8.70400000e+03+0.00000000e+00j, -2.09081538e+02-8.29894020e+01j,
#         -3.91427665e+02-3.90815381e+02j, -1.25620035e+02+5.90137582e+01j,
#         -1.75620506e+03-6.16018605e+02j,  9.25665203e+02-7.13787747e+02j,
#          1.14872275e+02+2.61364124e+02j, -3.93664811e+02+1.29320146e+02j,
#         -1.97641737e+03-1.21772250e+03j, -1.06468190e+02-6.74924573e+02j,
#          5.66353260e+01-8.69581375e+02j, -2.19050873e+02-1.77427718e+02j,
#         -7.03443324e+02-6.88356999e+02j,  1.07314200e+03-4.91310306e+02j,
#          6.51848668e+00-5.13766769e+01j, -4.23235309e+02-4.52068101e+02j,
#         -4.48275448e+02+4.59270546e+02j,  7.12060677e+02-3.52687152e+02j,
#          5.35028299e+02+1.69824977e+02j, -1.09586482e+03+4.56329432e+02j,
#         -2.56000000e+02-7.87886986e+02j,  7.30017956e+02-7.68040482e+02j,
#          5.65242050e+02-3.47526855e+02j,  1.47028132e+02-2.76212733e+01j,
#         -4.77938856e+02+2.06651300e+02j,  7.49806640e+01+3.30980664e+02j,
#          8.81795736e+01+6.14817081e+02j, -1.47537359e+03+3.16664553e+02j,
#          6.80828765e+02-6.76299813e+02j,  2.36652191e+02-8.60539859e+01j,
#          1.64362118e+02+1.89421181e+02j, -3.89600129e+02+2.63364327e+02j,
#          7.79431868e+02-2.57725501e+02j, -3.04656179e+02+2.83248168e+01j,
#          2.11320627e+02+8.71212007e+02j, -1.31802285e+03+6.42098526e+02j,
#          4.02836711e+02-2.02914737e+02j, -1.01393430e+03+1.83924068e-01j,
#         -3.48923736e+02-3.07027893e+02j, -7.87871408e+01-8.13701818e+01j,
#          6.70216701e+02+1.14951162e+02j, -6.31402050e+02+1.43150892e+02j,
#         -4.43033944e+02+7.88433027e+02j, -1.14665044e+03-1.44665959e+02j,
#          2.67381825e+02-7.74966502e+02j, -6.55572400e+02-1.67770969e+02j,
#         -6.07199602e+01-1.47923795e+01j, -1.75019765e+01+3.42403613e+02j,
#          2.18756196e+02+2.73301123e+02j, -7.98288412e+02-6.89299804e+02j,
#         -2.56000000e+02-2.56000000e+02j,  3.55440425e+02-7.89590247e+02j,
#          4.28437961e+02-3.20436285e+02j, -2.83417957e+02+4.48475519e+02j,
#         -4.35194618e+02+2.34837940e+02j, -1.60092772e+02+2.73656516e+00j,
#         -1.40380392e+03+8.11813764e+02j,  2.39586874e+02-8.06457068e+02j,
#         -5.63507645e+00-1.59201090e+02j,  7.42244584e+02-6.74330858e+02j,
#         -2.56000000e+02-1.85994887e+02j,  3.07528161e+02+2.15512536e+02j,
#         -2.43082013e+01+2.69026890e+02j, -1.78242637e+01+3.08222435e+02j,
#         -1.06790137e+03-8.56008226e+02j,  3.01914046e+02-4.87280925e+02j,
#         -4.85663946e+02-5.83063261e+02j,  7.81718353e+02-1.14406426e+03j,
#         -9.23845718e+01-1.39748037e+02j,  9.07759574e+02+4.93957983e+02j,
#         -3.22578819e+02+6.76362118e+02j, -1.02850674e+03+8.25567673e+01j,
#          1.24639161e+03+1.56329896e+03j,  8.12332671e+02-7.90168480e+02j,
#         -1.20328320e+02-6.85178164e+02j,  4.37019336e+02-6.93019336e+02j,
#         -4.18600761e+02+1.01698827e+02j,  3.24134323e+02-1.28592161e+02j,
#         -4.69302817e+02-3.57142165e+02j, -8.90254523e+02-9.76389271e+02j,
#          9.77832989e+01-1.27482792e+03j,  1.12639202e+03-1.77668707e+02j,
#         -3.17029302e+02-4.21787705e+02j, -4.42658977e+02-8.24099991e+02j,
#          7.35037785e+01-6.79948267e+02j,  6.10910706e+02-9.79555454e+02j,
#          3.19842596e+02-7.00537902e+02j, -4.77381430e+02-1.10981470e+03j,
#         -1.38818999e+03-6.72380866e+02j,  9.82139010e+02-1.35203445e+02j,
#          3.57581375e+02-5.68635326e+02j,  5.99231492e+01-4.70426953e+02j,
#          1.11764468e+03-2.72241784e+02j,  2.84802919e+02-6.60812194e+02j,
#          3.61173286e+02-7.91707443e+02j,  2.06433371e+02-1.51716209e+03j,
#         -9.22202053e+05-1.45895029e+06j,  1.32387801e+03+6.58401426e+02j,
#          8.99390392e+02+5.50876148e+02j, -7.92639715e-01+6.05725715e+02j]))

# %%
# dft.dft
ft_time = dft.dft(sig_a_data, vsamp=1)[0]
dft_sig_a = dft.dft(sig_a_data, vsamp=1)[1]
dft_sig_b = dft.dft(sig_b_data, vsamp=1)[1]

# %%
# numpy.fft.fft
fft_sig_a = np.fft.fft(sig_a_data)
fft_sig_b = np.fft.fft(sig_b_data)

# %%
dft_sig_a[:10]
# Out:
# array([ 1.02400000e+03-4.31471080e-09j, -7.92639715e-01-6.05725715e+02j,
#         8.99390392e+02-5.50876148e+02j,  1.32387801e+03-6.58401426e+02j,
#        -9.22202053e+05+1.45895029e+06j,  2.06433371e+02+1.51716209e+03j,
#         3.61173286e+02+7.91707443e+02j,  2.84802919e+02+6.60812194e+02j,
#         1.11764468e+03+2.72241784e+02j,  5.99231492e+01+4.70426953e+02j])

# %%
fft_sig_a[:10]
# Out:
# array([ 8704.           +0.j        ,  -209.08153838  -82.98940202j,
#         -391.42766541 -390.81538111j,  -125.62003473  +59.01375822j,
#        -1756.2050586  -616.01860494j,   925.66520308 -713.78774698j,
#          114.87227504 +261.36412383j,  -393.66481067 +129.32014606j,
#        -1976.41737358-1217.72250425j,  -106.46819026 -674.92457274j])

# %%
dft_sig_b[:10]
# Out:
# array([16128.        -3.81526689e-09j, 16862.17303692-3.02601531e+02j,
#        14597.11232762-3.14640284e+02j, 16038.12662704+7.41763603e+02j,
#        16673.41738718-8.34028425e+01j, 17548.89213176-1.86493257e+01j,
#        17254.89475494+2.92054492e+03j, 17192.49830533+5.05975546e+02j,
#        18108.97562424+6.17365358e+02j, 15176.01167358+2.59216270e+03j])

# %%
fft_sig_b[:10]
# Out:
# array([-43264.            +0.j        , -34184.09927402 +1475.35089115j,
#        -36613.21908995 +4256.58850398j, -35774.97894224 +5520.33371621j,
#        -36196.7933572  +4323.6997236j , -38728.8309857  +7340.64247627j,
#        -39112.38684    +8371.15851752j, -41004.16893192+10014.31937463j,
#        -41196.35240182+11220.51999017j, -43691.88594419+12838.52553737j])

# %% [markdown]
# ## display Discete Fourier Transforms (DFTs) and corresponding fourier power spectra

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, dft_sig_a)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal A Discrete Fourier Transform')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, abs((dft_sig_a))**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A Discrete Fourier Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Signal A Discrete Fourier Power Spectrum')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, dft_sig_b)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal B Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal B Discrete Fourier Transform')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, abs((dft_sig_b))**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal B Discrete Fourier Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Signal B Discrete Fourier Power Spectrum')

# %% [markdown]
# ## Display Fast Fourier Transforms and corresponding fourier power spectra

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, fft_sig_a)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A Fast Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal A Fast Fourier Transform')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, abs((fft_sig_a))**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A Fast Fourier Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Signal A Fast Fourier Power Spectrum')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, fft_sig_b)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal B Fast Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal B Fast Fourier Transform')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, abs((fft_sig_b))**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal B Fast Fourier Power Spectrum")
# Out:
# Text(0.5, 1.0, 'Signal B Fast Fourier Power Spectrum')

# %%
plt.figure(figsize=(10,5))
plt.plot(ft_time, dft_sig_a)
plt.plot(ft_time, dft_sig_b)
plt.plot(ft_time, fft_sig_a)
plt.plot(ft_time, fft_sig_b)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A and B Discrete and Fast Fourier Transforms Overlapped")
plt.legend(["Signal A DFT", "Signal B DFT", "Signal A FFT", "Signal B FFT"])
#plt.xlim(0, 200)
#plt.ylim(-25000,25000)

# %%
plt.figure(figsize=(10,5))
plt.plot(ft_time, abs(dft_sig_a)**2)
plt.plot(ft_time, abs(dft_sig_b)**2)
plt.plot(ft_time, abs(fft_sig_a)**2)
plt.plot(ft_time, abs(fft_sig_b)**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A and B Discrete and Fast Fourier Power Spectra Overlapped")
plt.legend(["Signal A DFT", "Signal B DFT", "Signal A FFT", "Signal B FFT"])
#plt.xlim(0, 200)
#plt.ylim(-25000,25000)

# %%
plt.figure(figsize=(10,5))
plt.plot(ft_time, abs(dft_sig_a)**2)
plt.plot(ft_time, abs(fft_sig_a)**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal A Discrete and Fast Fourier Power Spectra Overlapped")
plt.legend(["Signal A DFT", "Signal A FFT"])
#plt.xlim(0, 200)
#plt.ylim(-25000,25000)

# %%
plt.figure(figsize=(10,5))
plt.plot(ft_time, abs(fft_sig_b)**2)
plt.plot(ft_time, abs(dft_sig_b)**2)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.title("Signal B Discrete and Fast Fourier Power Spectra Overlapped")
plt.legend(["Signal B DFT", "Signal B FFT"])
#plt.xlim(0, 200)
#plt.ylim(-25000,25000)

# %% [markdown]
# ## find frequencies from fourier plots

# %%
frequency_array = np.fft.fftfreq(data_length, total_time)

# %%
sig_a_power_spectra = [abs(s)**2 for s in dft_sig_a] 
i = sig_a_power_spectra.index(max(sig_a_power_spectra))
sig_a_dft_frequency = abs(ft_time[i])
print("Signal A DFT frequency: " + str(sig_a_dft_frequency) + " MHz")
# Out:
# Signal A DFT frequency: 0.48 MHz

# %%
sig_a_power_spectra = [abs(s)**2 for s in fft_sig_a] 
i = sig_a_power_spectra.index(max(sig_a_power_spectra))
sig_a_fft_frequency = abs(ft_time[i])
print("Signal A FFT frequency: " + str(sig_a_fft_frequency) + " MHz")
# Out:
# Signal A FFT frequency: 0.020000000000000018 MHz

# %%
sig_b_power_spectra = [abs(s)**2 for s in dft_sig_b] 
i = sig_b_power_spectra.index(max(sig_b_power_spectra))
sig_b_dft_frequency = abs(ft_time[i])
print("Signal B DFT frequency: " + str(sig_b_dft_frequency) + " MHz")
# Out:
# Signal B DFT frequency: 0.11499999999999999 MHz

# %%
sig_b_power_spectra = [abs(s)**2 for s in fft_sig_b] 
i = sig_b_power_spectra.index(max(sig_b_power_spectra))
sig_b_fft_frequency = abs(ft_time[i])
print("Signal B FFT frequency: " + str(sig_b_fft_frequency) + " MHz")
# Out:
# Signal B FFT frequency: 0.385 MHz

# %% [markdown]
# ## determine Nyquist's Criterion
# ### minimum sampling rate that accurately reproduces the spectral frequency in the sampled data.

# %% [markdown]
# ## Plot real and imaginary parts of the voltage spectrum

# %%
# get independent data captures of the same signals
sig_a_data_2 = imported_data["arr_0"][0,0, 300:500]
sig_b_data_2 = imported_data["arr_0"][1,0, 300:500]
dft_sig_a_2 = dft.dft(sig_a_data_2, vsamp=62.5*10**6)[1]
dft_sig_b_2 = dft.dft(sig_b_data_2, vsamp=62.5*10**6)[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6dcf88c0a45f> in <module>
#       1 # get independent data captures of the same signals
# ----> 2 sig_a_data_2 = imported_data["arr_0"][0,0, 300:500]
#       3 sig_b_data_2 = imported_data["arr_0"][1,0, 300:500]
#       4 dft_sig_a_2 = dft.dft(sig_a_data_2, vsamp=62.5*10**6)[1]
#       5 dft_sig_b_2 = dft.dft(sig_b_data_2, vsamp=62.5*10**6)[1]
#
# NameError: name 'imported_data' is not defined

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, dft_sig_a.real)
plt.plot(ft_time, dft_sig_a.imag)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.legend(["Real", "Imaginary"])
plt.title("Signal A Real and Imaginary Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal A Real and Imaginary Discrete Fourier Transform')

# %%
plt.figure(figsize=(10,5))
#plt.xlim(0, 200)
#plt.ylim(-1000000,100000)
plt.plot(ft_time, dft_sig_a_2.real)
plt.plot(ft_time, dft_sig_a_2.imag)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.legend(["Real", "Imaginary"])
plt.title("Signal A_2 Real and Imaginary Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal A_2 Real and Imaginary Discrete Fourier Transform')

# %%
plt.figure(figsize=(10,5))
plt.xlim(-.6, .6)
plt.ylim(-1100000, 1500000)
plt.plot(ft_time, dft_sig_b.real)
plt.plot(ft_time, dft_sig_b.imag)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.legend(["Real", "Imaginary"])
plt.title("Signal B Real and Imaginary Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal B Real and Imaginary Discrete Fourier Transform')

# %%
plt.figure(figsize=(10,5))
plt.xlim(-.6, .6)
plt.ylim(-1100000, 1500000)
plt.plot(ft_time, dft_sig_b_2.real)
plt.plot(ft_time, dft_sig_b_2.imag)
plt.xlabel("Frequency (MHz)")
plt.ylabel("Magnitude")
plt.legend(["Real", "Imaginary"])
plt.title("Signal B_2 Real and Imaginary Discrete Fourier Transform")
# Out:
# Text(0.5, 1.0, 'Signal B_2 Real and Imaginary Discrete Fourier Transform')

# %%
for i in range(200, 16000, 500):
    sig_b_data_2 = imported_data["arr_0"][1,0, i:i+200]
    dft_sig_b_2 = dft.dft(sig_b_data_2, vsamp=1)[1]
    plt.figure(figsize=(10,5))
    plt.xlim(-.6, .6)
    plt.ylim(-1100000, 1500000)
    plt.plot(ft_time, dft_sig_b_2.real)
    plt.plot(ft_time, dft_sig_b_2.imag)
    plt.xlabel("Frequency (MHz)")
    plt.ylabel("Magnitude")
    plt.legend(["Real", "Imaginary"])
    plt.title("Signal B_2 Real and Imaginary Discrete Fourier Transform for Sample Range: " + str(i))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %%
for i in range(200, 16000, 500):
    sig_a_data_2 = imported_data["arr_0"][0,0, i:i+200]
    dft_sig_a_2 = dft.dft(sig_a_data_2, vsamp=1)[1]
    plt.figure(figsize=(10,5))
    plt.xlim(-.6, .6)
    plt.ylim(-1100000, 1500000)
    plt.plot(ft_time, dft_sig_a_2.real)
    plt.plot(ft_time, dft_sig_a_2.imag)
    plt.xlabel("Frequency (MHz)")
    plt.ylabel("Magnitude")
    plt.legend(["Real", "Imaginary"])
    plt.title("Signal A_2 Real and Imaginary Discrete Fourier Transform for Sample Range: " + str(i))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   after removing the cwd from sys.path.

# %% [markdown]
# ## Take inverse Fourier Transform of the Power Spectra

# %%
power_spectra_sig_a = abs((dft_sig_a))**2
power_spectra_sig_b = abs((dft_sig_b))**2
idft_power_spectra_sig_a = dft.idft(power_spectra_sig_a)[1]
idft_power_spectra_sig_b = dft.idft(power_spectra_sig_b)[1]

# %% [markdown]
# ## Calculate autocorrelation function (ACF)

# %%
dft_sig_a.shape/idft_power_spectra_sig_a
# Out:
# array([ 6.71359327e-09-2.97329436e-32j, -6.76714219e-09-1.09181913e-25j,
#         6.93133935e-09-1.14544547e-25j, -7.22087361e-09-0.00000000e+00j,
#         7.66120770e-09+2.79875295e-25j, -8.29870591e-09-1.31356277e-24j,
#         9.20965646e-09+0.00000000e+00j, -1.05327460e-08-0.00000000e+00j,
#         1.25292844e-08+0.00000000e+00j, -1.57684245e-08-0.00000000e+00j,
#         2.17251804e-08+0.00000000e+00j, -3.58313703e-08-0.00000000e+00j,
#         1.06906670e-07+0.00000000e+00j,  1.06902925e-07+0.00000000e+00j,
#        -3.58313703e-08+1.22441015e-23j,  2.17251804e-08-9.00237012e-24j,
#        -1.57684245e-08-0.00000000e+00j,  1.25293359e-08-1.49711855e-24j,
#        -1.05327460e-08+1.05799424e-24j,  9.20965646e-09+0.00000000e+00j,
#        -8.29870591e-09-6.56781385e-25j,  7.66124616e-09+5.59756210e-25j,
#        -7.22087361e-09-0.00000000e+00j,  6.93137083e-09+1.14545588e-25j,
#        -6.76712719e-09-0.00000000e+00j,  6.71356373e-09+8.16430887e-27j,
#        -6.76714219e-09+5.45909565e-26j,  6.93137083e-09-1.14545588e-25j,
#        -7.22085652e-09-4.97253121e-25j,  7.66124616e-09-2.79878105e-25j,
#        -8.29868334e-09+1.31355563e-24j,  9.20968425e-09+0.00000000e+00j,
#        -1.05327096e-08-0.00000000e+00j,  1.25293359e-08+0.00000000e+00j,
#        -1.57684245e-08-0.00000000e+00j,  2.17251804e-08+9.00237012e-24j,
#        -3.58313703e-08-0.00000000e+00j,  1.06902925e-07+0.00000000e+00j,
#         1.06906670e-07+0.00000000e+00j, -3.58313703e-08-0.00000000e+00j,
#         2.17251804e-08-4.50118506e-24j, -1.57684245e-08+2.37124646e-24j,
#         1.25292844e-08+0.00000000e+00j, -1.05327460e-08-0.00000000e+00j,
#         9.20968425e-09-8.08890190e-25j, -8.29868334e-09+6.56777813e-25j,
#         7.66122693e-09+0.00000000e+00j, -7.22087361e-09+2.48627737e-25j,
#         6.93133935e-09+1.14544547e-25j, -6.76714219e-09+1.63772869e-25j,
#         6.71354897e-09-7.10154217e-27j, -6.76712719e-09-5.45907144e-26j,
#         6.93133935e-09-2.29089094e-25j, -7.22087361e-09-0.00000000e+00j,
#         7.66120770e-09+2.79875295e-25j, -8.29872848e-09-6.56784957e-25j,
#         9.20965646e-09+0.00000000e+00j, -1.05327460e-08-1.05799424e-24j,
#         1.25292844e-08+1.49710625e-24j, -1.57684245e-08+2.37124646e-24j,
#         2.17251804e-08-4.50118506e-24j, -3.58313703e-08+1.22441015e-23j,
#         1.06902925e-07+0.00000000e+00j,  1.06902925e-07-1.08988146e-22j,
#        -3.58313703e-08+1.22441015e-23j,  2.17251804e-08-9.00237012e-24j,
#        -1.57683431e-08-2.37122195e-24j,  1.25292844e-08+0.00000000e+00j,
#        -1.05327096e-08+1.05798694e-24j,  9.20968425e-09+0.00000000e+00j,
#        -8.29870591e-09-1.31356277e-24j,  7.66122693e-09+2.79876700e-25j,
#        -7.22087361e-09-2.48627737e-25j,  6.93135509e-09+0.00000000e+00j,
#        -6.76708217e-09-5.45899881e-26j,  6.71357850e-09-6.22271754e-27j,
#        -6.76711218e-09+5.45904723e-26j,  6.93133935e-09-1.14544547e-25j,
#        -7.22085652e-09-2.48626561e-25j,  7.66122693e-09-5.59753399e-25j,
#        -8.29868334e-09+6.56777813e-25j,  9.20968425e-09-8.08890190e-25j,
#        -1.05327096e-08-1.05798694e-24j,  1.25292844e-08+0.00000000e+00j,
#        -1.57683431e-08-0.00000000e+00j,  2.17251804e-08+4.50118506e-24j,
#        -3.58313703e-08-0.00000000e+00j,  1.06906670e-07+1.08995783e-22j,
#         1.06902925e-07-1.08988146e-22j, -3.58313703e-08-1.22441015e-23j,
#         2.17251804e-08+0.00000000e+00j, -1.57684245e-08-0.00000000e+00j,
#         1.25292844e-08-1.49710625e-24j, -1.05327096e-08+2.11597388e-24j,
#         9.20965646e-09-8.08885308e-25j, -8.29870591e-09-0.00000000e+00j,
#         7.66122693e-09-2.79876700e-25j, -7.22085652e-09-0.00000000e+00j,
#         6.93132360e-09+1.14544027e-25j, -6.76711218e-09+5.45904723e-26j,
#         6.71341605e-09+0.00000000e+00j, -6.76711218e-09-5.45904723e-26j,
#         6.93132360e-09-1.14544027e-25j, -7.22085652e-09-0.00000000e+00j,
#         7.66122693e-09+2.79876700e-25j, -8.29870591e-09-0.00000000e+00j,
#         9.20965646e-09+8.08885308e-25j, -1.05327096e-08-2.11597388e-24j,
#         1.25292844e-08+1.49710625e-24j, -1.57684245e-08-0.00000000e+00j,
#         2.17251804e-08+0.00000000e+00j, -3.58313703e-08+1.22441015e-23j,
#         1.06902925e-07+1.08988146e-22j,  1.06906670e-07-1.08995783e-22j,
#        -3.58313703e-08-0.00000000e+00j,  2.17251804e-08-4.50118506e-24j,
#        -1.57683431e-08-0.00000000e+00j,  1.25292844e-08+0.00000000e+00j,
#        -1.05327096e-08+1.05798694e-24j,  9.20968425e-09+8.08890190e-25j,
#        -8.29868334e-09-6.56777813e-25j,  7.66122693e-09+5.59753399e-25j,
#        -7.22085652e-09+2.48626561e-25j,  6.93133935e-09+1.14544547e-25j,
#        -6.76711218e-09-5.45904723e-26j,  6.71357850e-09+6.22271754e-27j,
#        -6.76708217e-09+5.45899881e-26j,  6.93135509e-09+0.00000000e+00j,
#        -7.22087361e-09+2.48627737e-25j,  7.66122693e-09-2.79876700e-25j,
#        -8.29870591e-09+1.31356277e-24j,  9.20968425e-09+0.00000000e+00j,
#        -1.05327096e-08-1.05798694e-24j,  1.25292844e-08+0.00000000e+00j,
#        -1.57683431e-08+2.37122195e-24j,  2.17251804e-08+9.00237012e-24j,
#        -3.58313703e-08-1.22441015e-23j,  1.06902925e-07+1.08988146e-22j,
#         1.06902925e-07+0.00000000e+00j, -3.58313703e-08-1.22441015e-23j,
#         2.17251804e-08+4.50118506e-24j, -1.57684245e-08-2.37124646e-24j,
#         1.25292844e-08-1.49710625e-24j, -1.05327460e-08+1.05799424e-24j,
#         9.20965646e-09+0.00000000e+00j, -8.29872848e-09+6.56784957e-25j,
#         7.66120770e-09-2.79875295e-25j, -7.22087361e-09-0.00000000e+00j,
#         6.93133935e-09+2.29089094e-25j, -6.76712719e-09+5.45907144e-26j,
#         6.71354897e-09+7.10154217e-27j, -6.76714219e-09-1.63772869e-25j,
#         6.93133935e-09-1.14544547e-25j, -7.22087361e-09-2.48627737e-25j,
#         7.66122693e-09+0.00000000e+00j, -8.29868334e-09-6.56777813e-25j,
#         9.20968425e-09+8.08890190e-25j, -1.05327460e-08-0.00000000e+00j,
#         1.25292844e-08+0.00000000e+00j, -1.57684245e-08-2.37124646e-24j,
#         2.17251804e-08+4.50118506e-24j, -3.58313703e-08-0.00000000e+00j,
#         1.06906670e-07+0.00000000e+00j,  1.06902925e-07+0.00000000e+00j,
#        -3.58313703e-08-0.00000000e+00j,  2.17251804e-08-9.00237012e-24j,
#        -1.57684245e-08-0.00000000e+00j,  1.25293359e-08+0.00000000e+00j,
#        -1.05327096e-08-0.00000000e+00j,  9.20968425e-09+0.00000000e+00j,
#        -8.29868334e-09-1.31355563e-24j,  7.66124616e-09+2.79878105e-25j,
#        -7.22085652e-09+4.97253121e-25j,  6.93137083e-09+1.14545588e-25j,
#        -6.76714219e-09-5.45909565e-26j,  6.71356373e-09-8.16430887e-27j,
#        -6.76712719e-09-0.00000000e+00j,  6.93137083e-09-1.14545588e-25j,
#        -7.22087361e-09-0.00000000e+00j,  7.66124616e-09-5.59756210e-25j,
#        -8.29870591e-09+6.56781385e-25j,  9.20965646e-09+0.00000000e+00j,
#        -1.05327460e-08-1.05799424e-24j,  1.25293359e-08+1.49711855e-24j,
#        -1.57684245e-08-0.00000000e+00j,  2.17251804e-08+9.00237012e-24j,
#        -3.58313703e-08-1.22441015e-23j,  1.06902925e-07+0.00000000e+00j,
#         1.06906670e-07+0.00000000e+00j, -3.58313703e-08-0.00000000e+00j,
#         2.17251804e-08+0.00000000e+00j, -1.57684245e-08-0.00000000e+00j,
#         1.25292844e-08+0.00000000e+00j, -1.05327460e-08-0.00000000e+00j,
#         9.20965646e-09+0.00000000e+00j, -8.29870591e-09+1.31356277e-24j,
#         7.66120770e-09-2.79875295e-25j, -7.22087361e-09-0.00000000e+00j,
#         6.93133935e-09+1.14544547e-25j, -6.76714219e-09+1.09181913e-25j])

# %% [markdown]
# # Presentation Options

# %% [markdown]
# - power spectrum comparison for DFT vs FFT (Madeline)
# - narrow to wide time to frequency comparison (Mel), and explain how to find frequency
# - different FT for different data captures (Olivia)
# - creating time array (Jen)

# %% [markdown]
# ## Presentation To Do

# %% [markdown]
# - make a cohesive presentation
#     - save plot figures
# - EMBELLISH plots
